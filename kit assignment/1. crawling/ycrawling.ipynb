# %%
from selenium import webdriver
import undetected_chromedriver as uc
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
    

    
cn = []
scroll_count = 5
    
def ycrawling(eid, pw):
        
    from selenium import webdriver
    import undetected_chromedriver as uc
    from selenium.webdriver.chrome.options import Options
    from selenium.webdriver.common.by import By
    import time
        
    options = Options()
    options.add_argument("--start-maximized")
    options.add_argument("disable-gpu")
        
    driver = uc.Chrome(options=options)
    driver.get('https://youtube.com')
    
    driver.find_element(By.XPATH,'//*[@id="buttons"]/ytd-button-renderer/yt-button-shape/a/yt-touch-feedback-shape/div/div[2]').click()
    id_input = driver.find_element(By.XPATH,'//*[@id="identifierId"]').send_keys(eid)
    driver.find_element(By.XPATH, '//*[@id="identifierNext"]/div/button/span').click()
    time.sleep(6)
    pw_input = driver.find_element(By.XPATH, '//*[@id="password"]/div[1]/div/div[1]/input').send_keys(pw)
    driver.find_element(By.XPATH, '//*[@id="passwordNext"]/div/button/span').click()
        
    time.sleep(5)
    click = driver.find_element(By.XPATH, '//*[@id="dismissible"]/div[3]/ytd-button-renderer/yt-button-shape/button/yt-touch-feedback-shape/div/div[2]').click()
    time.sleep(1)

    for _ in range(scroll_count):
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(1)
        
    rows = driver.find_element(By.XPATH, '//*[@id="contents"]')
    time.sleep(0.5)
    contents = rows.find_elements(By.XPATH, '//*[@id="video-title-link"]')
    channel_name = rows.find_elements(By.XPATH, '//*[@id="text"]/a')

    for i in channel_name:
        cn.append(i.text)
    
    #for i, cont in enumerate(contents):
        #if "list" in cont.get_attribute("href"):
            #continue
        #conts.append({'title' : cont.get_attribute("title"), 'link' : cont.get_attribute("href"), "channel_name" : channel_name[i].text})
        #cn.append(channel_name[i].text)
 
    driver.quit()
    print("유튜브 크롤링 완료")
    
    c_crawling(cn)

def c_crawling(cn):
    print("카테고리 크롤링",end =" ")


    cn_ca = {}
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}

    for i in cn:
        cn_link = f"https://youtube-rank.com/board/bbs/search.php?sfl=wr_subject%7C%7Cwr_content%7C%7Cdescription&stx={i}"
        res = requests.get(cn_link, headers=headers)
        soup = BeautifulSoup(res.text, 'lxml')
        a = soup.select("#list-skin > table > tbody > tr:nth-child(1) > td.subject > div.subject_description.img_padding > h1 > a:nth-child(1) > span")
        
        print("·",end =" ")
        
        for i in a:
            i = str(i)
            c1 = str(i).find("[")
            c2 = str(i).rfind("]")
            tc = i[c1+1:c2]
            if i[c1+1:c2] in cn_ca:
                cn_ca[i[c1+1:c2]] += 1
            else :
                cn_ca[i[c1+1:c2]] = 1
            
            
    del cn_ca["미분류"]
    cn_ca1 = sorted(cn_ca.items(), key=lambda x: x[1], reverse=True)
    cn_ca1 = [dict(cn_ca1)]
    cn_ca_df = pd.DataFrame(cn_ca1, index = ['category'])
    cn_ca_df.to_csv('algorithm.csv',index=False,encoding='utf-8-sig')
    print("완료")
    
    
eid = input("id : ")
pw = input("pw : ")
ycrawling(eid, pw)
# Out:
# id : a
# pw : a
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[6], line 100
#      98 eid = input("id : ")
#      99 pw = input("pw : ")
# --> 100 ycrawling(eid, pw)
#
# Cell In[6], line 28, in ycrawling(eid, pw)
#      25 options.add_argument("disable-gpu")
#      27 driver = uc.Chrome(options=options)
# ---> 28 driver.get('https://youtube.com')
#      30 driver.find_element(By.XPATH,'//*[@id="buttons"]/ytd-button-renderer/yt-button-shape/a/yt-touch-feedback-shape/div/div[2]').click()
#      31 id_input = driver.find_element(By.XPATH,'//*[@id="identifierId"]').send_keys(eid)
#
# File ~\anaconda3\Lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# ...

# %%
cn = ['뮤직 위크', 'MBCNEWS', '셀럽무비', 'Ghibli Music', '동현kldh', '탤탤 Tale', '오분순삭', '백종원 PAIK JONG WON', '스튜디오지니', '뜬뜬 DdeunDdeun', '파비앙 Fabien Yoon', '요정재형', 'KFATV_대한민국 축구 국가대표팀', '육식맨 YOOXICMAN', 'Tottenham Hotspur', '채널A 캔버스', '피식대학Psick Univ', '파뿌리', '스튜디오지니', 'SBS 뉴스', 'The Rolling Stones', '', '딩고 뮤직 / dingo music', 'essential;', 'JM', 'JTBC Voyage', '슈카월드', '펭귄몬스터', '엠빅뉴스', 'KBS Entertain: 깔깔티비', '기분Jazz네 | Mood is Jazz', '소박사TV', 'DRAMA Voyage', '문화인 - MUN HWA IN', '풋볼매거진']
cn_ca = []
print(cn)
link = "https://vling.net/search"
driver.get(link)

for i in cn:
    link = "https://vling.net/search"
    driver.get(link)
    ele = driver.find_element(By.CSS_SELECTOR,"input.SearchBar_searchBar__Qoord")
    time.sleep(0.3)
    ele.send_keys(i)
    ele.send_keys("\n")
    time.sleep(0.3)
    ca = driver.find_element(By.CSS_SELECTOR,"li.Category_category__mcSYi")
    cn_ca.append({ca.text : 0})
    if ca.text in cn_ca :
        cn_ca[ca.text] += 1
print(cn_ca)
driver.quit()

# 링크를 들어가보면 Let's confirm you are human이 나와 크롤링을 하기 어려워서 다른 사이트를 사용하기로 함
# Out:
# ['지무비 : G Movie', '오마이TV', '동현kldh', '엠뚜루마뚜루 : MBC 공식 종합 채널', '건나물TV', '엠뚜루마뚜루 : MBC 공식 종합 채널', '리쥬라이크 LIJULIKE', '채널 십오야', '재밌는 거 올라온다', '말하는동물원 뿌빠TV', '너덜트', '오분순삭', 'The CHOOM (더 춤)', '뜬뜬 DdeunDdeun', '스튜디오지니', '요정재형', 'KFATV_대한민국 축구 국가대표팀', 'SBS 뉴스', '셀럽무비', '발라드 명곡', 'KBS 다큐', '풋볼매거진', 'JTBC News', 'MBCNEWS', '짤툰', '딩고 뮤직 / dingo music', '파뿌리', '장사의 신', '오마이TV', 'K-POP STARS', 'KBS News', ' YTN', '하이픽션']
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}
for i in cn:
    cn_link = f"https://vling.net/search?keyword={i[0]}"
    print(cn_link)
    res = requests.get(cn_link, headers=headers)
    soup = BeautifulSoup(res.text, 'lxml')
    #print(soup.select(".Category_category__mcSYi"))

# 링크를 들어가보면 Let's confirm you are human이 나와 크롤링을 하기 어려워서 다른 사이트를 사용하기로 함
# Out:
# https://vling.net/search?keyword=지무비 : G Movie
# []
# https://vling.net/search?keyword=스포타임
# []
# https://vling.net/search?keyword=MBCNEWS
# []
# https://vling.net/search?keyword=발라드 명곡
# []
# https://vling.net/search?keyword=산부인과 미나쌤
# []
# https://vling.net/search?keyword=딩고 뮤직 / dingo music
# []
# https://vling.net/search?keyword=엠뚜루마뚜루 : MBC 공식 종합 채널
# []
# https://vling.net/search?keyword=말하는동물원 뿌빠TV
# []
# https://vling.net/search?keyword=말하는동물원 뿌빠TV
# []
# https://vling.net/search?keyword=너덜트
# []
# https://vling.net/search?keyword=파비앙 Fabien Yoon
# []
# https://vling.net/search?keyword=뜬뜬 DdeunDdeun
# []
# https://vling.net/search?keyword=Tottenham Hotspur
# []
# https://vling.net/search?keyword=엠뚜루마뚜루 : MBC 공식 종합 채널
# []
# https://vling.net/search?keyword=숏박스
# []
# https://vling.net/search?keyword=엔조이커플enjoycouple
# []
# https://vling.net/search?keyword=파뿌리
# []
# https://vling.net/search?keyword=동현kldh
# []
# https://vling.net/search?keyword= YTN
# []
# ...
