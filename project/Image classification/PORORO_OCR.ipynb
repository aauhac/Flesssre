#  57% [.........................................                               ] 43868160 / 76920376
#  60% [...........................................                             ] 46432256 / 76920376
#  63% [.............................................                           ] 48955392 / 76920376
#  66% [................................................                        ] 51322880 / 76920376
#  69% [..................................................                      ] 53706752 / 76920376
#  72% [....................................................                    ] 56033280 / 76920376
#  76% [......................................................                  ] 58597376 / 76920376
#  79% [.........................................................               ] 61120512 / 76920376
#  82% [...........................................................             ] 63643648 / 76920376
#  86% [.............................................................           ] 66191360 / 76920376
#  89% [................................................................        ] 68706304 / 76920376
#  92% [..................................................................      ] 71081984 / 76920376
#  95% [....................................................................    ] 73564160 / 76920376
#  98% [....................................................................... ] 75939840 / 76920376
# 100% [........................................................................] 76920376 / 76920376
# 100% [..............................................................................] 92382 / 92382

# %% [markdown]
# 현재 지원 가능하는 언어는 영어와 한국어 입니다.

# %%
ocr.get_available_langs()
# Out:
# ['en', 'ko']

# %%
ocr.get_available_models()
# Out:
# {'en': ['brainocr'], 'ko': ['brainocr']}

# %% [markdown]
# **Examples**
# ```python
# ocr = Pororo(task='ocr', lang='ko')
# ocr(IMAGE_PATH)
# ```

# %%
img_path = 'assets/images/test_image_5.jpg'

# %%
ocr.run_ocr(img_path, debug=True)
# Out:
# ['관리핵임자',
#  "백접주무관 관력부시 교양교적과정부 (G10호 '~780 777",
#  '국제시회이애의 강의실 변경 DBI25호 - 금오공과대학교',
#  'kit',
#  'B125 대강의실 Lecture Room']

# %%
ocr.get_ocr_result()
# Out:
# {'description': ['관리핵임자',
#   "백접주무관 관력부시 교양교적과정부 (G10호 '~780 777",
#   '국제시회이애의 강의실 변경 DBI25호 - 금오공과대학교',
#   'kit',
#   'B125 대강의실 Lecture Room'],
#  'bounding_poly': [{'description': '관리핵임자',
#    'vertices': [{'x': 725, 'y': 139},
#     {'x': 765, 'y': 139},
#     {'x': 765, 'y': 153},
#     {'x': 725, 'y': 153}]},
#   {'description': "백접주무관 관력부시 교양교적과정부 (G10호 '~780 777",
#    'vertices': [{'x': 689, 'y': 169},
#     {'x': 771, 'y': 169},
#     {'x': 771, 'y': 202},
#     {'x': 689, 'y': 202}]},
#   {'description': '국제시회이애의 강의실 변경 DBI25호 - 금오공과대학교',
#    'vertices': [{'x': 870, 'y': 395},
#     {'x': 1050, 'y': 395},
#     {'x': 1050, 'y': 578},
#     {'x': 870, 'y': 578}]},
#   {'description': 'kit',
#    'vertices': [{'x': 463, 'y': 423},
#     {'x': 493, 'y': 423},
#     {'x': 493, 'y': 439},
#     {'x': 463, 'y': 439}]},
#   {'description': 'B125 대강의실 Lecture Room',
#    'vertices': [{'x': 438, 'y': 470},
#     {'x': 520, 'y': 470},
#     {'x': 520, 'y': 553},
#     {'x': 438, 'y': 553}]}]}
